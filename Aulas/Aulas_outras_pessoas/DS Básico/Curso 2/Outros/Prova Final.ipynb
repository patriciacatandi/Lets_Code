# %% [markdown]
# # **PROVA**
#
# <font color='red'>**Orientações:**</font>
#
# - **Não codar aqui, porque todo mundo vê**.
# - Apesar de algumas funções pedirem para implementar uma função não desista caso não saiba o assunto, faça do seu jeito.
# - De preferência tente responder as questões na ordem e com a resposta logo abaixo da pergunta.
# - Vocês podem entregar em .py ou .ipynb, mas é necessário ter o texto da questão em cima do código.
# - Não colem entre vocês. Essa atividade não é para reprovar ninguém. Queremos entender melhor como está o curso para vocês! Por isso, mesmo se não souber tente fazer :).

# %% [markdown]
# ### **Questão 1**
#
# Vamos praticar o uso de Slices em Numpy Arrays:
#
# __A)__ Crie um array com 20 números sequenciais
#
# __B)__ Crie um slice que selecione somente as posições pares do array (0, 2, 4, 6, 8, ...)
#
# __C)__ Crie um slice que selecione somente as posições impares do array (1, 3, 5, 7, 9, ...)
#
# __D)__ Crie um slice que selecione do 5 ao 10 elemento
#
# __E)__ Crie um slice que inverta o array
#
# __F)__ Crie um slice inverte somente os dois ultimos elementos e retorna uma lista com 2 elementos

# %% [markdown]
# ### Questão 2
#
# Nesse desafio, iremos praticar o conceito de indexação em imagens! Pois é, caso você ainda não saiba, as imagens são formadas com conjuntos de pixels, e esses pixels são números inteiros (entre 0 e 255). Sendo assim, quando carregamos uma imagem no Python, essa imagem será armazenada em um matriz (Numpy), ou seja, cada pixel dessa imagem será um elemento dessa matriz.
#
# No entanto, é importante que você também saiba que uma imagem colorida é composta por três matrizes, visto que uma imagem colorida é formada por 3 cores básicas: vermelho, verde e azul. Esse é o famoso padrão RGB. Portanto, sua imagem será armazenada em um array tridimensional.
#
# Sabendo disso, sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical. Mas, calma... vamos te dar uma ajuda.
#
# Primeiro, você precisa instalar a biblioteca skimage para carregar a imagem, além da biblioteca do matplotlib para exibir a imagem (veremos essa biblioteca com mais detalhes nesse curso!), caso você ainda não tenha elas instaladas, claro. Para isso, utilize o comando pip install scikit-image matplotlib, se você estiver utilizando o pip, ou conda install scikit-image matplotlib, se estiver utilizando o Anaconda.
#
# Em seguida, observe o código abaixo; ele te mostra como você pode carregar uma imagem e exibi-la. Lembrando... Sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical.

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('https://www.kindpng.com/picc/m/713-7136289_rougier-numpy-logo-name-below-02-python-numpy.png') # Carregamento da imagem

print(type(img))

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Questão 3
#
# Vamos praticar o desenvolvimento de funções e operações com NumPy:
#
# __A)__ Desenvolva uma função chamada `cria_matriz` que receba os parâmetros (a, b, m, rs), onde [a, b] são o intervalos para os números aleatórios (onde b > a), m vai ser a dimensão da matriz quadrada m x m e rs é o número da semente aleatória (caso não seja passado nenhum valor utilizar o `None`);
#
# __B)__ Qual o resultado da multiplicação `cria_matriz(-6, 8, 4, 0)` por `cria_matriz(1, 50, 4, 0)`?

# %% [markdown]
# ### Questão 4
#
# Crie um objeto DataFrame que contenha os dados da tabela abaixo, os quais se referem ao peso, altura e idade de cinco pessoas:
#
#
# | Peso (kg) | Altura (cm) | Idade (anos) |
# |-----------|-------------|--------------|
# |  47 | 161	| 31 |
# |  80 | 170	| 21 |
# |  60 | 175	| 16 |
# |  90 | 162	| 28 |
# | 100 | 185	| 23 |
# | 147 | 189 | 32 |
#
# Com base no DataFrame criado, realize o que pedido nos itens abaixo:
#
# __A)__ Visualize apenas os dados da coluna que contém a altura das pessoas;
#
# __B)__ Obtenha a idade média das pessoas;
#
# __C)__ Obtenha os dados das pessoas que estão abaixo da altura média;
#
# __D)__ Crie um nova coluna no DataFrame que contenha o IMC (Índice de Massa Corporal) de cada pessoa;
#
# __Obs.:__ A fórmula para o IMC é dada por IMC = Peso/(Altura)² com o peso em kg e a altura em metros.
#
# __E)__ Remova a coluna que contém a idade das pessoas;
#
# __F)__ Crie uma nova coluna chamada Classificação, que contenha a classificação de cada indivíduo, de acordo com o seu IMC. Para isso, consulte a tabela abaixo.
#
# | IMC             | Classificação |
# |-----------------|---------------|
# Menor que 18,5    | Subpeso |
# Entre 18,5 e 24,9 | Normal |
# Entre 25,0 e 29,9 | Sobrepeso |
# Entre 30,0 e 39,9 | Obesidade Grau I |
# Maior que 40,0    | Obesidade Grau II |
#
# __G)__ Salve esses dados do DataFrame em um arquivo csv.

# %% [markdown]
# ### Questão 5
#
# Utilizando a base de dados do [`IBOV.csv`](https://drive.google.com/file/d/1llDQB-yL5-IYFtEmtLnIieV6FaItAu7k/view?usp=sharing), vamos trabalhar os dados antes de criar as visualizações:
#
# __A)__ Filtre os dados para trabalharmos apenas com o segundo trimestre de 2020;
#
# __B)__ Crie uma coluna chamada de `Amplitude`, onde esse dado será a diferença entre o valor da alta no dia (`High`) menos o valor da baixa no dia (`Low`);
#
# __C)__ Crie um gráfico que demonstre a variação da `Amplitude` ao longo do segundo trimestre;
#
# __D)__ Crie um gráfico que demonstre a distribuição da `Amplitude`, destacando cada um dos quartis e os _Outliers_.
#
# __E)__ Faça o mesmo gráfico para a `Amplitude` e adicionalmente coloque a linha de valor médio no período e marque todos os pontos que sejam considerados como _outliers_.

# %% [markdown]
# ### Questão 6
#
# Um teste para COVID-19 possui uma taxa de 5% de falso positivo e 1% de falso negativo, ou seja, em 5% dos não-infectados acusa como infectados, e em 1% dos infectados acusa como não infectados. Sabendo que atualmente 1% da população está infectada.
#
# Calcule a probabilidade de um paciente cujo teste apontou positivo estar realmente infectado.

# %% [markdown]
# ### Questão 7
#
# Um programa de computador gera uma pontuação aleatória para cada usuário, sendo que:
#
# - Em 1/2 dos casos, gera 0.5;
# - Em 1/4 dos casos, gera 0.25;
# - Em 1/8 dos casos, gera 0.125.
#
# E essa lógica segue assim por diante. Resolva os itens a seguir:
#
# __A)__ Calcule o __valor esperado__ utilizando apenas os 3 primeiros casos;
#
# __B)__ Faça um _loop_ para calcular o __valor esperado__ para 100 casos e avalie se só com os 3 primeiros casos temos uma boa aproximação ou não.

# %% [markdown]
# ### Questão 8
# Faça o download do _dataset_ [`Titanic.csv`](https://drive.google.com/file/d/1JPvsa3g5mBeZNxS6i8v3AL8vqFq_-zS8/view?usp=sharing):
#
# __A)__ Utilizando a coluna `Age` do _dataset Titanic_, calcule e explique as principais métricas estatísticas para essa variável tais como:
#
# - Média;
# - Desvio Padrão;
# - Mínimo;
# - Primeiro Quartil;
# - Segundo Quartil (Mediana);
# - Terceiro Quartil;
# - Distância Interquartil (IQR);
# - Máximo;
# - Skewness;
# - Moda.
#
# __B)__ Crie um gráfico da dispersão das idades dos passageiros do _Titanic_ e identifique os pontos onde se encontram a média, mediana e moda das idades.

# %% [markdown]
# ### **Questão 9**
#
# Descreva conceitualmente a necessidade de separar um conjunto de dados em treino e teste. Comente também conceitualmente pelo menos duas estratégias para fazer essa separação.

# %% [markdown]
# ### **Questão 10**
#
# Descreva conceitualmente o que é um _outlier_ e quais técnicas podem ser utilizadas para evita-los

# %% [markdown]
# ### Questão 11
#
# Você acaba de receber uma base de dados e ao fazer um **describe()** se depara com os seguintes resultados:
#
# ![image-2.png](attachment:image-2.png)
#
# Ao analisar a tabela, você decide não normalizar os dados e então fazer um modelo de regressão Linear para prever o preço dos imóvel.
#
# __A)__ Não fazer a normalização neste caso, esta correto? Justifique
#
# __B)__ Quais variáveis você usaria para `X` e quais para `Y`?

# %% [markdown]
# ### Questão 12
#
# Explique como funciona cada um dos modelos abaixo e de um exemplo de quando é bom utilizar o modelo e quando não é bom:
#
# - Regressão Linear
# - Regressão Polinomial
# - Regressão Logistica
# - Árvore de decisão simples
# - Floresta randômica
# - AdaBoost
# - KNN

# %% [markdown]
# ### Questão 13
#
# Com base em tudo que você aprendeu no curso, faça uma analise do dataset abaixo.
#
# Seu objetivo é entender a base de dados e montar um storytelling com as informações que achar mais relevantes.
#
# __dica__: Neste dataset, existem pelo menos 4 variávies que podem ser usadas para fazer predições (Default, limite_credito, iteracoes_12m, meses_inativo_12m)

# %% [markdown]
# ### Dataset
#
# [Download Dataset: Crédito](https://drive.google.com/file/d/1W1L4Dp3OsnpijvC7CFu5s3XrJ7eTv38B/view?usp=sharing)
#
# ### dados:
#
# Representam as informações de clientes de um banco X:
#
# **Features:**
# - default: Quando uma pessoa (física ou jurídica) não consegue cumprir com suas obrigações financeiras
# - idade: idade do cliente
# - sexo: sexo do cliente (F ou M)
# - dependentes: número de dependentes do cliente
# - escolaridade: nível de escolaridade do clientes
# - salario_anual: faixa salarial do cliente
# - tipo_cartao: tipo de cartao do cliente
# - qtd_produtos: quantidade de produtos comprados nos últimos 12 meses
# - iteracoes_12m: quantidade de iterações/transacoes nos ultimos 12 meses
# - meses_inativo_12m: quantidade de meses que o cliente ficou inativo nos ultimos 12 meses
# - limite_credito: limite de credito do cliente
# - valor_transacoes_12m: valor médio das transações dos ultimos 12 meses
# - qtd_transacoes_12m: quantidade de transacoes dos ultimos 12 meses
